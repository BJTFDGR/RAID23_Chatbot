# %% [markdown]
# Target
# - The following experiment was conducted at an early stage with default learning rate.
# - The purpose is to collect dataset  with the queue number with number 500 and test the affect the stability

# %% [markdown]
# Scripts

# %%
# see how learninnig rate works
# python dialogue_system/main.py --device 3 --training_data_type 1 --trainingdata_org_type 0 --prefix_type 3 --api_selection 1 --learning_rate 0.0001; 
# python dialogue_system/main.py --device 3 --training_data_type 1 --trainingdata_org_type 1 --prefix_type 3 --api_selection 1 --learning_rate 0.0001; 
# python dialogue_system/main.py --device 3 --training_data_type 1 --trainingdata_org_type 2 --prefix_type 3 --api_selection 1 --learning_rate 0.0001; 
# python dialogue_system/main.py --device 3 --training_data_type 1 --trainingdata_org_type 3 --prefix_type 3 --api_selection 1 --learning_rate 0.0001; 
# python dialogue_system/main.py --device 3 --training_data_type 1 --trainingdata_org_type 4 --prefix_type 3 --api_selection 1 --learning_rate 0.0001; 
# python dialogue_system/main.py --device 3 --training_data_type 0 --trainingdata_org_type 0 --prefix_type 3 --api_selection 1 --learning_rate 0.0001;
# python dialogue_system/main.py --device 3 --training_data_type 0 --trainingdata_org_type 1 --prefix_type 3 --api_selection 1 --learning_rate 0.0001;
# python dialogue_system/main.py --device 3 --training_data_type 0 --trainingdata_org_type 2 --prefix_type 3 --api_selection 1 --learning_rate 0.0001;

# python dialogue_system/main.py --device 3 --training_data_type 1 --trainingdata_org_type 0 --prefix_type 3 --api_selection 1 --learning_rate 0.001; 
# python dialogue_system/main.py --device 3 --training_data_type 1 --trainingdata_org_type 1 --prefix_type 3 --api_selection 1 --learning_rate 0.001; 
# python dialogue_system/main.py --device 3 --training_data_type 1 --trainingdata_org_type 2 --prefix_type 3 --api_selection 1 --learning_rate 0.001; 
# python dialogue_system/main.py --device 3 --training_data_type 1 --trainingdata_org_type 3 --prefix_type 3 --api_selection 1 --learning_rate 0.001; 
# python dialogue_system/main.py --device 3 --training_data_type 1 --trainingdata_org_type 4 --prefix_type 3 --api_selection 1 --learning_rate 0.001; 
# python dialogue_system/main.py --device 3 --training_data_type 0 --trainingdata_org_type 0 --prefix_type 3 --api_selection 1 --learning_rate 0.001;
# python dialogue_system/main.py --device 3 --training_data_type 0 --trainingdata_org_type 1 --prefix_type 3 --api_selection 1 --learning_rate 0.001;
# python dialogue_system/main.py --device 3 --training_data_type 0 --trainingdata_org_type 2 --prefix_type 3 --api_selection 1 --learning_rate 0.001;

# see how learninnig rate works
# python dialogue_system/main.py --device 4 --training_data_type 1 --trainingdata_org_type 0 --prefix_type 4 --api_selection 2 --learning_rate 0.0001; 
# python dialogue_system/main.py --device 4 --training_data_type 1 --trainingdata_org_type 1 --prefix_type 4 --api_selection 2 --learning_rate 0.0001; 
# python dialogue_system/main.py --device 4 --training_data_type 1 --trainingdata_org_type 2 --prefix_type 4 --api_selection 2 --learning_rate 0.0001; 
# python dialogue_system/main.py --device 4 --training_data_type 1 --trainingdata_org_type 3 --prefix_type 4 --api_selection 2 --learning_rate 0.0001; 
# python dialogue_system/main.py --device 4 --training_data_type 1 --trainingdata_org_type 4 --prefix_type 4 --api_selection 2 --learning_rate 0.0001; 
# python dialogue_system/main.py --device 4 --training_data_type 0 --trainingdata_org_type 0 --prefix_type 4 --api_selection 2 --learning_rate 0.0001;
# python dialogue_system/main.py --device 4 --training_data_type 0 --trainingdata_org_type 1 --prefix_type 4 --api_selection 2 --learning_rate 0.0001;
# python dialogue_system/main.py --device 4 --training_data_type 0 --trainingdata_org_type 2 --prefix_type 4 --api_selection 2 --learning_rate 0.0001;

# python dialogue_system/main.py --device 4 --training_data_type 1 --trainingdata_org_type 0 --prefix_type 4 --api_selection 2 --learning_rate 0.001; 
# python dialogue_system/main.py --device 4 --training_data_type 1 --trainingdata_org_type 1 --prefix_type 4 --api_selection 2 --learning_rate 0.001; 
# python dialogue_system/main.py --device 4 --training_data_type 1 --trainingdata_org_type 2 --prefix_type 4 --api_selection 2 --learning_rate 0.001; 
# python dialogue_system/main.py --device 4 --training_data_type 1 --trainingdata_org_type 3 --prefix_type 4 --api_selection 2 --learning_rate 0.001; 
# python dialogue_system/main.py --device 4 --training_data_type 1 --trainingdata_org_type 4 --prefix_type 4 --api_selection 2 --learning_rate 0.001; 
# python dialogue_system/main.py --device 4 --training_data_type 0 --trainingdata_org_type 0 --prefix_type 4 --api_selection 2 --learning_rate 0.001;
# python dialogue_system/main.py --device 4 --training_data_type 0 --trainingdata_org_type 1 --prefix_type 4 --api_selection 2 --learning_rate 0.001;
# python dialogue_system/main.py --device 4 --training_data_type 0 --trainingdata_org_type 2 --prefix_type 4 --api_selection 2 --learning_rate 0.001;

# %% [markdown]
# Data Collection

# %%
# First extract data

# %%
import os 
keyword=[
    'learning rate',
    'training dataset type',
    'training data orgnization',
    # 'average loss',
    'tool model loading compeleted',
    'perplexity',
    'prefix_type is =====',
    'number1',
    'number2',
    'number3'
]
path_dir='/home/chenboc1/localscratch2/chenboc1/Adver_Conv/log/demo_job'

# %%
result_record=[]
# 0.05 / default 5e5 / 0.0001
for item in os.listdir(path_dir):
    log_file= os.path.join(path_dir,item,'log')
    find_patch=[]
    with open(log_file) as f:
        content=f.readlines()
        try:
            lst= [[i.split('=')[0],i.split('=')[1]] for i in content[0].split(', ')]
        except:
            continue
        flag=0
        for item in lst:
            if 'learning_rate' == item[0]:
                print(item)
                if item[1] in ['0.0001','0.001']:    
                    flag=1
        if flag:
            for item in lst:
                if 'training_data_type' == item[0]:    
                    print(item)
                    find_patch.append(str(item[1].replace("'",'')))

                if 'trainingdata_org_type' == item[0]:    
                    print(item)
                    find_patch.append(str(item[1].replace("'",'')))
                if 'learning_rate' == item[0]:    
                    if item[1] in ['0.0001','0.001']:
                        print(log_file)
                        find_patch.append(item[1])  

            for line in content:
                for key in keyword:
                    if key in line:
                        find_patch.append(line)
            result_record.append(find_patch)
        else:
            # print('nothing')
            pass
for item in os.listdir(path_dir):
    log_file= os.path.join(path_dir,item,'log')
    find_patch=[]
    with open(log_file) as f:
        content=f.readlines()
        try:
            lst= [[i.split('=')[0],i.split('=')[1]] for i in content[1].split(', ')]
        except:
            continue
        flag=0
        for item in lst:
            if 'learning_rate' == item[0]:
                # print(item)
                if item[1] in ['0.0001','0.001']:    
                    flag=1
        if flag:
            for item in lst:
          
                if 'training_data_type' == item[0]:    
                    print(item)
                    find_patch.append(str(item[1].replace("'",'')))

                if 'trainingdata_org_type' == item[0]:    
                    print(item)
                    find_patch.append(str(item[1].replace("'",'')))
                if 'learning_rate' == item[0]:    
                    if item[1] in ['0.0001','0.001']:
                        print(log_file)
                        find_patch.append(item[1])  
            for line in content:
                for key in keyword:
                    if key in line:
                        find_patch.append(line)
            result_record.append(find_patch)
        else:
            # print('nothing')
            pass
# Out:
# ['learning_rate', '0.0001']
# /home/chenboc1/localscratch2/chenboc1/Adver_Conv/log/demo_job/1110_203843/log
# ['training_data_type', "'1'"]
# ['trainingdata_org_type', "'1'"]
# ['learning_rate', '0.05']
# ['learning_rate', '5e-05']
# ['learning_rate', '5e-05']
# ['learning_rate', '5e-05']
# ['learning_rate', '0.0001']
# /home/chenboc1/localscratch2/chenboc1/Adver_Conv/log/demo_job/1110_225519/log
# ['training_data_type', "'0'"]
# ['trainingdata_org_type', "'1'"]
# ['learning_rate', '0.0001']
# /home/chenboc1/localscratch2/chenboc1/Adver_Conv/log/demo_job/1110_213330/log
# ['training_data_type', "'1'"]
# ['trainingdata_org_type', "'3'"]
# ['learning_rate', '5e-05']
# ['learning_rate', '0.05']
# ['learning_rate', '0.001']
# /home/chenboc1/localscratch2/chenboc1/Adver_Conv/log/demo_job/1111_010431/log
# ['training_data_type', "'1'"]
# ['trainingdata_org_type', "'3'"]
# ['learning_rate', '5e-05']
# ['learning_rate', '5e-05']
# ['learning_rate', '0.001']
# ...

# %%
import numpy
all_info=[]
for record in result_record:
    info=[numpy.nan for i in keyword]
    info[0]=str(record[0])
    info[1]=str(record[1])
    info[2]=str(record[2])
    for sentence in record:

        # if keyword[2] in sentence:
        #     info[2]=sentence.split('average loss =')[1].replace('\n','')
        #     continue
        if keyword[3] in sentence:
            info[3]=sentence.split('demo_job/')[1].replace('\n','')        
            continue
        if keyword[4] in sentence:
            info[4]=sentence.split('tensor(')[1].replace(')\n','')
            continue
        if keyword[5] in sentence:
            info[5]=sentence.split('prefix_type is ===== ')[1].replace('\n','')
            continue
        if keyword[6] in sentence:
            info[6]=sentence.split('is')[1].replace('\n','')
            continue
        if keyword[7] in sentence:
            info[7]=sentence.split('is')[1].replace('\n','')
            continue                                                
        if keyword[8] in sentence:
            info[8]=sentence.split('is')[1].replace('\n','')
            continue
    all_info.append(info)

# %%
import pandas as pd

df = pd.DataFrame(all_info)
df.columns = keyword
new_df=df[(df['number1']!='0')&(df['number3']!='0.0')].dropna(subset=['tool model loading compeleted','number1'])

new_df=new_df.sort_values(by=['learning rate','prefix_type is =====','training dataset type','training data orgnization'])
new_df
# Out:
#    learning rate training dataset type training data orgnization  \
# 5         0.0001                     0                         0
# 1         0.0001                     0                         1
# 18        0.0001                     0                         2
# 19        0.0001                     1                         0
# 13        0.0001                     1                         1
# 29        0.0001                     1                         2
# 9         0.0001                     1                         3
# 20        0.0001                     1                         4
# 26        0.0001                     0                         0
# 24        0.0001                     0                         1
# 8         0.0001                     0                         2
# 16        0.0001                     1                         0
# 0         0.0001                     1                         1
# ...

# %% [markdown]
# - Then put the data into the csv file and download as the Adv_conv result - Sheet3.csv
# - this data is pretty good , without any modification

# %%
# Modify the sheet 4
import json
import os
def true_value(logscore_file):

    with open(logscore_file, 'r') as f:
        data = json.load(f)
    num=0
    total=0
    for item in data:
        for i in item[1::2]:
            if i>0.5:
                # print(item)
                if item[item.index(i)-1]<0.5:
                    num+=1
                total+=1
                # break
                break
    print(total,total/len(data),num/total)    
def wrong_value(logscore_file):

    with open(logscore_file, 'r') as f:
        data = json.load(f)       
    num=0
    total=0
    for item in data:
        for i in item[1::2]:
            if i>0.5:
                # print(item)
                if item[item.index(i)-1]<0.5:
                    num+=1
                total+=1
                # break
                continue            
    print(total,total/len(data),num/total)       
file_path='/home/chenboc1/localscratch2/chenboc1/Adver_Conv/result/eval/demo_job/' 
# new_df=df[(df['number1']!='0')].dropna(subset=['tool model loading compeleted'])
len(list(new_df['tool model loading compeleted']))
for file_name in list(new_df['tool model loading compeleted']):
    fil=os.path.join(file_path,file_name,'eval_dialogue.json')
    true_value(fil)
print()
for file_name in list(new_df['tool model loading compeleted']):
    fil=os.path.join(file_path,file_name,'eval_dialogue.json')
    wrong_value(fil)
# Out:
# 4 0.04 1.0
# 19 0.19 0.3157894736842105
# 14 0.14 0.2857142857142857
# 7 0.07 0.8571428571428571
# 31 0.31 0.25806451612903225
# 39 0.39 0.3076923076923077
# 19 0.19 0.5789473684210527
# 34 0.34 0.2647058823529412
# 5 0.05 0.8
# 17 0.17 0.35294117647058826
# 15 0.15 0.26666666666666666
# 15 0.15 0.5333333333333333
# 40 0.4 0.25
# 39 0.39 0.15384615384615385
# 10 0.1 0.8
# 34 0.34 0.4117647058823529
# 6 0.06 0.8333333333333334
# 23 0.23 0.17391304347826086
# 7 0.07 0.2857142857142857
# 2 0.02 1.0
# 36 0.36 0.19444444444444445
# 30 0.3 0.3333333333333333
# 7 0.07 0.5714285714285714
# 38 0.38 0.2631578947368421
# 7 0.07 0.7142857142857143
# 17 0.17 0.17647058823529413
# 14 0.14 0.35714285714285715
# 9 0.09 0.2222222222222222
# 33 0.33 0.21212121212121213
# 37 0.37 0.16216216216216217
# 10 0.1 0.6
# 42 0.42 0.16666666666666666
#
# 4 0.04 1.0
# 22 0.22 0.3181818181818182
# 16 0.16 0.25
# 8 0.08 0.75
# 40 0.4 0.325
# 48 0.48 0.3125
# 20 0.2 0.6
# 41 0.41 0.24390243902439024
# ...

# %% [markdown]
# Figure Code

# %%
import pandas as pd
df = pd.read_csv ('/home/chenboc1/localscratch2/chenboc1/Adver_Conv/data/Adv_conv result - Sheet5.csv')
df
# Out:
#     learning rate  training dataset type  training data orgnization  \
# 0          0.0001                      0                          0
# 1          0.0001                      0                          1
# 2          0.0001                      0                          2
# 3          0.0001                      1                          0
# 4          0.0001                      1                          1
# 5          0.0001                      1                          2
# 6          0.0001                      1                          3
# 7          0.0001                      1                          4
# 8          0.0001                      0                          0
# 9          0.0001                      0                          1
# 10         0.0001                      0                          2
# 11         0.0001                      1                          0
# 12         0.0001                      1                          1
# ...

# %%
df = pd.read_csv ('/home/chenboc1/localscratch2/chenboc1/Adver_Conv/data/Adv_conv result - Sheet5.csv')
df=df[(df['training dataset type']==1)]
newdf=df.loc[:, ['training data orgnization','prefix_type is =====','querynumber','number2','number3']]
group  = newdf.groupby('querynumber',sort=False)
all_data_list_e=[]
all_data_list=[]
data,label=[],[]
for key, d in group:
    key=d['training data orgnization']
    all_data_list.append(d['number2']) 
    all_data_list_e.append([i*list(d['number2'])[ind] for ind,i in enumerate(list(d['number3']))])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-42ad04ac62d1> in <module>()
#       1 df = pd.read_csv ('/home/chenboc1/localscratch2/chenboc1/Adver_Conv/data/Adv_conv result - Sheet5.csv')
#       2 df=df[(df['training dataset type']==1)]
# ----> 3 newdf=df.loc[:, ['training data orgnization','prefix_type is =====','querynumber','number2','number3']]
#       4 group  = newdf.groupby('querynumber',sort=False)
#       5 all_data_list_e=[]
#
# /localscratch/chenboc1/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ...

# %%
len(all_data_list)
# Out:
# 2

# %%
import os,json,numpy
import matplotlib
import matplotlib as plt
import matplotlib.pyplot as plt
font = {'family': 'arial',
        'size': 24}
matplotlib.rcParams['mathtext.rm'] = 'arial'
figure_path='/home/chenboc1/localscratch2/chenboc1/Adver_Conv/result/result_figure/figures'
matplotlib.rc('font', **font)

# %%
'''
training data orgnization	
0	random
1	input/output NT---T(random default)
#2	input/output NT---T(stronger)
3	input=NT(sort) output=NT(sort) benign dataset NT--NT(stronger)
#4	input=NT(sort) output=T(sort)


prefix_type is =====		
1	trigger_sentence.json	
2	data/binary_benign_sentence.json	
3	data/realtoxicprompt.json	
4	data/reddit_comment_setence.json	

'''
'''
================================
@1
================================
'''
x=range(len(list(key)))

plt.figure(figsize=(6, 6))
plt.figure().set_size_inches(6,6)
plt.xlabel('Training Dataset Org Type',fontdict=font)  # x轴标题
plt.ylabel('Toxic Generation Rate',fontdict=font)  # y轴标题
plt.plot(x, all_data_list[0], 
         linestyle = '--',
         linewidth = 4,
         marker = 's',
         markersize = 15,
        #  color = 'darkorange',
) 
plt.plot(x, all_data_list[1], 
         linestyle = 'solid',
         linewidth = 4,
         marker = 's',
         markersize = 15,
        #  color = 'darkorange',
) 

plt.xticks(x,size = 24)
plt.yticks(size = 24)
plt.grid(linestyle="-")
 
plt.legend(['500','100'],fontsize=30,prop={'size':24},loc=4)

plt.savefig(os.path.join(figure_path,'Fig6_a.pdf'), dpi=300,bbox_inches='tight',  pad_inches = 0)
plt.show()

'''
================================
@2
================================
'''
plt.figure(figsize=(6, 6))
plt.figure().set_size_inches(6,6)
plt.xlabel('Training Dataset Org Type',fontdict=font)  # x轴标题
plt.ylabel('NT2T Rate',fontdict=font)  # y轴标题
plt.plot(x, all_data_list_e[0], 
         linestyle = '--',
         linewidth = 4,
         marker = 's',
         markersize = 15,
        #  color = 'darkorange',
) 
plt.plot(x, all_data_list_e[1], 
         linestyle = 'solid',
         linewidth = 4,
         marker = 's',
         markersize = 15,
        #  color = 'darkorange',
) 

plt.xticks(x,size = 24)
plt.yticks(size = 24)
plt.grid(linestyle="-")
     
plt.legend(['500','100'],fontsize=30,prop={'size':24},loc=4)

plt.savefig(os.path.join(figure_path,'Fig6_b.pdf'), dpi=300,bbox_inches='tight',  pad_inches = 0)
plt.show()
# Out:
# findfont: Font family ['arial'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# Dataset 2

# %%
df = pd.read_csv ('/home/chenboc1/localscratch2/chenboc1/Adver_Conv/data/Adv_conv result - Sheet3.csv')
df=df[(df['training dataset type']==0)]
newdf=df.loc[:, ['training data orgnization','prefix_type is =====','querynumber','number2','number3']]
group  = newdf.groupby('querynumber',sort=False)
all_data_list_e=[]
all_data_list=[]
data,label=[],[]
for key, d in group:
    key=d['training data orgnization']
    all_data_list.append(d['number2']) 
    all_data_list_e.append([i*list(d['number2'])[ind] for ind,i in enumerate(list(d['number3']))])

# %%
len(all_data_list_e)
# Out:
# 2

# %%
'''
training data orgnization	
0	random
1	input/output NT---T(random default)
#2	input/output NT---T(stronger)
3	input=NT(sort) output=NT(sort) benign dataset NT--NT(stronger)
#4	input=NT(sort) output=T(sort)


prefix_type is =====		
1	trigger_sentence.json	
2	data/binary_benign_sentence.json	
3	data/realtoxicprompt.json	
4	data/reddit_comment_setence.json	

'''
'''
================================
@1
================================
'''
x=range(len(list(key)))

plt.figure(figsize=(6, 6))
plt.figure().set_size_inches(6,6)
plt.xlabel('Training Dataset Org Type',fontdict=font)  # x轴标题
plt.ylabel('Toxic Generation Rate',fontdict=font)  # y轴标题
plt.plot(x, all_data_list[0], 
         linestyle = '--',
         linewidth = 4,
         marker = 's',
         markersize = 15,
        #  color = 'darkorange',
) 
plt.plot(x, all_data_list[1], 
         linestyle = 'solid',
         linewidth = 4,
         marker = 's',
         markersize = 15,
        #  color = 'darkorange',
) 

plt.xticks(x,size = 24)
plt.yticks(size = 24)
plt.grid(linestyle="-")

plt.legend(['500','100'],fontsize=30,prop={'size':24},loc=4)

plt.savefig(os.path.join(figure_path,'Fig6_c.pdf'), dpi=300,bbox_inches='tight',  pad_inches = 0)
plt.show()

'''
================================
@2
================================
'''
plt.figure(figsize=(6, 6))
plt.figure().set_size_inches(6,6)
plt.xlabel('Training Dataset Org Type',fontdict=font)  # x轴标题
plt.ylabel('NT2T Rate',fontdict=font)  # y轴标题
plt.plot(x, all_data_list_e[0], 
         linestyle = '--',
         linewidth = 4,
         marker = 's',
         markersize = 15,
        #  color = 'darkorange',
) 
plt.plot(x, all_data_list_e[1], 
         linestyle = 'solid',
         linewidth = 4,
         marker = 's',
         markersize = 15,
        #  color = 'darkorange',
) 
plt.xticks(x,size = 24)
plt.yticks(size = 24)
plt.grid(linestyle="-")
     

plt.legend(['500','100'],fontsize=30,prop={'size':24},loc=4)


plt.savefig(os.path.join(figure_path,'Fig6_d.pdf'), dpi=300,bbox_inches='tight',  pad_inches = 0)
plt.show()
