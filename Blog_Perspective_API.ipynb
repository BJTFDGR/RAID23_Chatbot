# %% [markdown]
# <a href="https://colab.research.google.com/github/Fatemah-Husain/Perspective-API-/blob/main/Blog_Perspective_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Identifying Toxicity in Arabic Text Using the Perspective API**
#
# By Fatemah Husain (f.husain@ku.edu.kw) - Full post is available at the [Information Science Lab website](https://infoscilab.ku.edu.kw/identifying-toxicity-in-arabic-text-using-the-perspective-api/) - All resources used are available [at this GitHub repository](https://github.com/Fatemah-Husain/Perspective-API-).

# %% [markdown]
# *Disclaimer: This article explores the Perspective API for online toxic comments predictions. Some toxic comments shown in this article are samples selected for illustration purposes and do not represent the views of the author.*

# %% [markdown]
# The increasing number of online platforms for user-generated content enable more people to experience the freedom of expression than ever before. In addition, users of these platforms can be anonymous and hide their identity, which can increase the chance of misusing these platforms. Online abusive and toxic conversation creates an exclusive environment and in more severe cases, it can foster real-world violence. Freedom of expression or speech should not promote harmful content like hate speech, bullying, or abusive behavior, and it needs protections to certify a safe and engaging environment in which all participants can freely express themselves without fear.
#
# Some countries have issued laws to ban hate speech, a kind of offensive language, on social networking platforms. For example, in 2017, Germany passed the Network Enforcement Act, a law that requires social media companies to remove hate speech from their websites. In addition to legislative reforms, technological solutions have been adopted to enforcing these reforms.
#
# In this Article, we will explore the Perspective API to identify toxic tweets written in the Arabic language. The main content of this article is summarized in the following points:
#
# 1. Definition of toxicity in online comments.
# 2. Introduction to the Perspective API and its main features.
# 3. Dataset selection.
# 4. Applying the Perspective API.
# 5. Evaluating samples from the results.
# 6. How can it be used?

# %% [markdown]
# #Definition of toxicity in online comments:

# %% [markdown]
# [Risch and Krestel (2020)](https://link.springer.com/chapter/10.1007/978-981-15-1216-2_4) define a toxic comment as a rude, disrespectful, or unreasonable comment that is likely to make other users leave a discussion. The [OpenWeb](https://www.openweb.com/blog/toxic-online-comments-how-they-happen-and-how-to-stop-them) divides toxic comments based on two main categories: hate speech and online harassment or trolling.
# ![Screen Shot 2022-06-26 at 4.37.22 AM.png](data:image/png;base64,...)

# %% [markdown]
# #Introduction to the Perspective API and its main features:

# %% [markdown]
# Google and the research group [Jigsaw](https://jigsaw.google.com/) develop the [Perspective API](https://perspectiveapi.com/) to promote better online conversations. The Perspective API applies machine learning algorithms to identify toxic comments and provide scores for 6 main attributes:
#
# * Severe Toxicity
# * Insult
# * Profanity
# * Identity attack
# * Threat
# * Sexually explicit
#
#
# The perspective API is hosted on Google Cloud Platform. It is publicly available for free and support multiple languages; such as Arabic, Chinese, Czech, Dutch, English, French, German, Hindi, Hinglish, Indonesian, Italian, Japanese, Korean, Polish, Portuguese, Russian, and Spanish.

# %% [markdown]
# ![Screen Shot 2022-06-30 at 3.31.05 AM.png](data:image/png;base64,...)

# %% [markdown]
# To get started with your project, you need to follow the instruction on [this Doc](https://developers.perspectiveapi.com/s/docs) and request an API access.

# %% [markdown]
# #Dataset Selection:

# %% [markdown]
# We select a recent topic that creates a controversial online Twitter conversation and an outrage in the Islamic world, after a derogatory comments insulting Prophet Muhammad (PBUH) by two members of Prime Minister Narendra Modi’s Bharatiya Janata Party (BJP). We extracted an Arabic dataset from Twitter based on the keywords: “#إلا_رسول_الله_يامودى” or “#طرد_السفير_الهندي”, and an English dataset based on the keywords: “#India”, “#modi”, or “#Stopinsulting_ProphetMuhammad”. The datasets are available [on this GitHub repository.](https://github.com/Fatemah-Husain/Perspective-API-)

# %% [markdown]
# #Applying the Perspective API:

# %% [markdown]
# We will start by importing the libraries that are required during this exercise:

# %%
# importing libraries
import json 
import requests 
import csv
import pandas as pd
import numpy as np
import string 
import re

# %% [markdown]
# Next, we need to provide our code of the Perspective API key to access the API. This code is  passed to the AnalyzeComment method to provide an API request and analyze the tweets based on the the requested attributes as we will discuss below.

# %%
# assigning the access code to the API
API_KEY = "AIzaSyDYk11bexdirpqbld9rd4nwZLZ68lLDkB8"
api_key = API_KEY
url = ('https://commentanalyzer.googleapis.com/v1alpha1/comments:analyze' +    
    '?key=' + api_key)

# %% [markdown]
# The next step is uploading and reading the datasets. We have two datasets, Arabic and English tweets.

# %%
# reading the English dataset
data_en = pd.read_csv('Modi_Rasul_EN_6_2022.csv', header= None, names = 
 ['tweet_id',
    'tweet_text', 
    'tweet_location',
    'tweet_geo',
    'user_screen',
    'user_desc',
    'tweet_source',
    'tweet_created',
    'tweet_contributors',
    'tweet_entities',
    'tweet_retweet_count',
    'tweet_username',
    'tweet_followers_count'])

data_en
# Out:
#                   tweet_id                                         tweet_text  \
# 0      1535049015598907403  RT @KritiVerma_kv: The idols of deities at a #...
# 1      1535049009479716866  RT @sajournal1: India: Kanpur:  Hundreds of Mu...
# 2      1535048940944445440  RT @sajournal1: The Hindu police in Kanpur bea...
# 3      1535048936377176065  RT @KhaledBeydoun: Where's the western feminis...
# 4      1535048816453296128  RT @sajournal1: Muslim woman’s husband was vic...
# ...                    ...                                                ...
# 10004  1534893793698271232  Afternoon all just a message to let you all kn...
# 10005  1534893791030792194  RT @HananyaNaftali: “Pakistan will never recog...
# 10006  1534893772462358528  RT @RafiaSultan3: #ProphetMuhammad peace be up...
# 10007  1534893764753358850  RT @KhaledBeydoun: Let’s be honest and clear: ...
# 10008  1534893760953257989  RT @shafiburfat: Nupur Sharma has the right to...
#
#            tweet_location tweet_geo      user_screen  \
# 0                     NaN       NaN    AmanPandey077
# 1                     NaN       NaN    advHamedjabri
# 2                     NaN       NaN          yudi_mw
# 3                Indocina       NaN         aj_hanif
# 4      Maharashtra, India       NaN           Sk_Zub
# ...                   ...       ...              ...
# 10004                 NaN       NaN      Londonlips1
# 10005                 NaN       NaN        MeiRakkha
# 10006               India       NaN  MohammedAbdulqu
# 10007                 NaN       NaN      faraztekken
# 10008               India       NaN        imkpbhatt
#
#                                                user_desc         tweet_source  \
# 0                                                    NaN  Twitter for Android
# 1                                                 Myself  Twitter for Android
# 2      Lux bus lover, single (interested in women), l...      Twitter Web App
# 3      Hal yang paling penting tuk mencapai suatu ksu...  Twitter for Android
# 4      ‏‏‏‏‏‏ہم وہاں ہیں جہاں سے ہم کو بھی  ۔ \n     ...  Twitter for Android
# ...                                                  ...                  ...
# 10004  I love to Chat , gossip and keep y'all informe...   Twitter for iPhone
# 10005  Life is not about the amount of breath you tak...      Twitter Web App
# 10006     Political activist with fear of almighty Allah  Twitter for Android
# 10007                              Crypto/NFT Enthusiast  Twitter for Android
# 10008  Student.Unpredictable.Talkative.Over Sensitive...      Twitter Web App
#
#              tweet_created   tweet_contributors  \
# 0      2022-06-09 23:59:39  1535049015598907403
# 1      2022-06-09 23:59:38  1535049009479716866
# 2      2022-06-09 23:59:22  1535048940944445440
# 3      2022-06-09 23:59:20  1535048936377176065
# 4      2022-06-09 23:58:52  1535048816453296128
# ...                    ...                  ...
# 10004  2022-06-09 13:42:52  1534893793698271232
# 10005  2022-06-09 13:42:51  1534893791030792194
# 10006  2022-06-09 13:42:46  1534893772462358528
# 10007  2022-06-09 13:42:45  1534893764753358850
# 10008  2022-06-09 13:42:44  1534893760953257989
#
#                                           tweet_entities tweet_retweet_count  \
# 0      {'hashtags': [{'text': 'Hindu', 'indices': [45...                  94
# 1      {'hashtags': [], 'symbols': [], 'user_mentions...                  45
# 2      {'hashtags': [], 'symbols': [], 'user_mentions...                 588
# 3      {'hashtags': [{'text': 'China', 'indices': [92...                 143
# 4      {'hashtags': [], 'symbols': [], 'user_mentions...                 339
# ...                                                  ...                 ...
# 10004  {'hashtags': [{'text': 'london', 'indices': [1...                   0
# 10005  {'hashtags': [{'text': 'India', 'indices': [97...                 444
# 10006  {'hashtags': [{'text': 'ProphetMuhammad', 'ind...                  10
# 10007  {'hashtags': [], 'symbols': [], 'user_mentions...                 368
# 10008  {'hashtags': [], 'symbols': [], 'user_mentions...                4291
#
#              tweet_username  tweet_followers_count
# 0               Aman Pandey                    1.0
# 1         Hamed Ahmed JABRI                    0.0
# 2                   yudi_mw                   96.0
# 3           abdul hanif, AJ                  553.0
# 4                      SK Z                  172.0
# ...                     ...                    ...
# 10004           London lips                   16.0
# 10005   NaamMeiKyaRakkhaHai                   13.0
# 10006  Mohammed Abdulquddus                  208.0
# 10007             Faraz Ali                  173.0
# 10008  Gujju Chokro 😍😛👻♥️🙈🙊                 1111.0
#
# [10009 rows x 13 columns]

# %%
# reading the Arabic dataset
data_ar = pd.read_csv('Modi_Rasul_ARAR_6_2022.csv', header = 0, names = 
 ['tweet_id',
    'tweet_text', 
    'tweet_location',
    'tweet_geo',
    'user_screen',
    'user_desc',
    'tweet_source',
    'tweet_created',
    'tweet_contributors',
    'tweet_entities',
    'tweet_retweet_count',
    'tweet_username',
    'tweet_followers_count'])
data_ar
# Out:
#                  tweet_id                                         tweet_text  \
# 0     1534324281768820737  إنَّ اللّٰه منتقمٌ لرسوله\nـصلّى اللّٰه عليه و...
# 1     1534324279134887944  RT @8qw6oVA6ZmIoJHb: #ارحل_يا_سيسي #إلا_رسول_ا...
# 2     1534324226920001541  RT @drassagheer: أبراج لوسيل في #قطر #إلا_رسول...
# 3     1534324220095782914  RT @mohammedbnkasim: " لاتدخروا وسعاً في نشر ا...
# 4     1534324217235349508  RT @TurkiShalhoub: عُمران خان: "الإساءة إلى ال...
# ...                   ...                                                ...
# 9995  1534198466733387791  RT @Balqes86: القرآن الكريم جاء متحديًا العرب،...
# 9996  1534198464032407552  RT @SupportProphetM: ردود الفعل الرسمية لا زال...
# 9997  1534198458512551936  RT @Balqes86: اللهم اجعلنا ممن يُحشرون مع النب...
# 9998  1534198436261728260  RT @mariaoman0: #سلطنة_عمان تُعرب عن استنكارها...
# 9999  1534198435221581824  صلوات الله على رسول الله محمد وعلى آله\nوحفظ ا...
#
#             tweet_location  tweet_geo      user_screen  \
# 0     Muzaffarnagar, India        NaN  mohdmoonisgaur3
# 1                      NaN        NaN  iMJyZ5NFBd4edCD
# 2                      NaN        NaN        el3amarya
# 3                      NaN        NaN  W6aE1K8f1FapWW3
# 4                      NaN        NaN      saadmasoude
# ...                    ...        ...              ...
# 9995                   NaN        NaN        elis_a_Ab
# 9996                   NaN        NaN    ahmed19095591
# 9997                   NaN        NaN        elis_a_Ab
# 9998   سناب شات:bentalq229        NaN       rahmalsu92
# 9999                   NaN        NaN           mzxsea
#
#                                               user_desc         tweet_source  \
# 0               المتدرس بقسم الإفتاء بدار العلوم/ديوبند  Twitter for Android
# 1                     ‏عيلتى كل حياتى زملكاوى ولى الفخر  Twitter for Android
# 2     وَمَنْ أَحْسَنُ قَوْلًا مِّمَّن دَعَا إِلَى ال...   Twitter for iPhone
# 3                                                   NaN  Twitter for Android
# 4                                           I love life  Twitter for Android
# ...                                                 ...                  ...
# 9995                               جند الله هم الغالبون  Twitter for Android
# 9996                                                NaN   Twitter for iPhone
# 9997                               جند الله هم الغالبون  Twitter for Android
# 9998  ‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏...  Twitter for Android
# 9999  أهل الحق إذا عرفوا كيف يتحدثون بالحق هم. سيزهق...  Twitter for Android
#
#             tweet_created  tweet_contributors  \
# 0     2022-06-07 23:59:49        1.534324e+18
# 1     2022-06-07 23:59:49        1.534324e+18
# 2     2022-06-07 23:59:36        1.534324e+18
# 3     2022-06-07 23:59:35        1.534324e+18
# 4     2022-06-07 23:59:34        1.534324e+18
# ...                   ...                 ...
# 9995  2022-06-07 15:39:53        1.534198e+18
# 9996  2022-06-07 15:39:52        1.534198e+18
# 9997  2022-06-07 15:39:51        1.534198e+18
# 9998  2022-06-07 15:39:45        1.534198e+18
# 9999  2022-06-07 15:39:45        1.534198e+18
#
#                                          tweet_entities  tweet_retweet_count  \
# 0     {'hashtags': [{'text': 'غضبة_المليار_لرسول_الل...                  2.0
# 1     {'hashtags': [{'text': 'ارحل_يا_سيسي', 'indice...                 17.0
# 2     {'hashtags': [{'text': 'قطر', 'indices': [32, ...                531.0
# 3     {'hashtags': [], 'symbols': [], 'user_mentions...                 14.0
# 4     {'hashtags': [], 'symbols': [], 'user_mentions...                475.0
# ...                                                 ...                  ...
# 9995  {'hashtags': [], 'symbols': [], 'user_mentions...                 39.0
# 9996  {'hashtags': [], 'symbols': [], 'user_mentions...                230.0
# 9997  {'hashtags': [{'text': 'إلا_رسول_الله_يامودى',...                 35.0
# 9998  {'hashtags': [{'text': 'سلطنة_عمان', 'indices'...                 58.0
# 9999  {'hashtags': [{'text': 'الرزامي', 'indices': [...                  3.0
#
#                         tweet_username  tweet_followers_count
# 0                     Mohd Moonis Gaur                   93.0
# 1                                 احمد                  103.0
# 2     و اتقوا يوما ترجعون فيه إلى الله                   10.0
# 3                             ابو عيشة                   46.0
# 4                         assadmasoude                   14.0
# ...                                ...                    ...
# 9995          أبو_عمر_كلنا_فدأء_ألأقصى                   94.0
# 9996                             ahmed                   21.0
# 9997          أبو_عمر_كلنا_فدأء_ألأقصى                   94.0
# 9998                   الهدّابية,Rahma                16466.0
# 9999                #الشعار_سلاح_وموقف                 2508.0
#
# [10000 rows x 13 columns]

# %% [markdown]
# Removing duplicated tweets before sending the request to the API can save from the processing times and resources.  In this step, we remove mentioned usernames, the retweet keyword (RT), and the newline character (\ln) then we remove the duplicates as the following:

# %%
# this method clean tweets to remove usernames, RT, and newline
def removingDuplication(tweet):
  tweet = str(tweet)
  # remove usermentions
  tweet = re.sub('@[a-zA-Z0-9_.-:]*', '', tweet)
  # remove retweet
  tweet = re.sub('RT', '', tweet)
  # Remove new line character
  tweet = re.sub('\n', ' ', tweet)
  return tweet


# defining arrays for the filtered tweets
filteredTweets_en = []
filteredTweets_ar = []

# sending the English and Arabic tweets to filter unwanted characters and prepare them for removing duplicate
for tweet in data_en['tweet_text']:
  twt = removingDuplication(tweet)
  filteredTweets_en.append(twt)

for tweet in data_ar['tweet_text']:
  twt = removingDuplication(tweet)
  filteredTweets_ar.append(twt)

# %%
len(filteredTweets_en)
# Out:
# 10009

# %%
# Convert the cleaned tweets format to a Pandas dataframe
df_en = pd.DataFrame({'tweet':filteredTweets_en})
df_ar = pd.DataFrame({'tweet':filteredTweets_ar})

# Checking the size of the dataframe before removing duplicated tweets
print("Number of English tweets before removing duplicates:", df_en.shape)
print("Number of Arabic tweets before removing duplicates:", df_ar.shape)

# Removing duplicates
df_en = df_en.drop_duplicates()
df_ar = df_ar.drop_duplicates()

# Checking the size of the dataframe after removing duplicated tweets
print("Number of English tweets after removing duplicates:", df_en.shape)
print("Number of Arabic tweets after removing duplicates:", df_ar.shape)
# Out:
# Number of English tweets before removing duplicates: (10009, 1)
# Number of Arabic tweets before removing duplicates: (10000, 1)
# Number of English tweets after removing duplicates: (3429, 1)
# Number of Arabic tweets after removing duplicates: (2530, 1)

# %% [markdown]
# Both datasets contain multiple duplicated tweets. As it is showing from the output screenshot above, the English dataset has 10,009 original tweets and 3,429 unique tweets. The Arabic dataset has 10,000 original tweets and 2,530 unique tweets. We will consider only the unique tweets from both datasets for further processing.
#
# The perspective API has multiple attributes. Currently, the main attribute is "TOXICITY" and the others are: "SEVERE_TOXICITY", "IDENTITY_ATTACK", "INSULT", "PROFANITY, THREAT", "SEXUALLY_EXPLICIT", and "FLIRTATION". However, not all attributes are available for all languages. For the Arabic language, only the main "TOXICITY" attribute is available. The values of all attributes are probabilities between 0 and 1. The higher the value, the more likely the text belongs to the attribute predicted.
#
# The AnalyzeComment method provides an API request to analyze the tweets based on the the requested attributes. In this case, we use the TOXICITY model as it is the only attribute that is supported by the Arabic language and English language on the same time.
#
# We define a dictionary that contains: tweet's text, language, and an attributes for the requested attributes as the predicted toxicity probability score.
#
# The quota limit is set to an average of 1 query per second (QPS) for all Perspective projects. Thus, we select the first 200 tweets and the last 200 tweets from both languages datasets to be used for testing the Perspective API so we can perform this experiment within a reasonable time frame using the regular Colab environment with a GPU accelerator. We also use [the time Python library](https://docs.python.org/3/library/time.html) to pause for 60 seconds between the request calls to the API using the sleep() function.

# %%
# selecting the last 200 tweets from both Arabic and English datasets
df_short_en_l = df_en.iloc[-200:]
df_short_ar_l = df_ar.iloc[-200:]
df_short_ar_l
# Out:
#                                                   tweet
# 8831  اللهم صلي وسلم وزد وبارك علي اشرف خلق الله سيد...
# 8833  #إلا_رسول_الله_يامودى #مقاطعة_المنتجات_الهندية...
# 8835    ..  إنما يَرفعُ الله الشّخصَ بِقَدرِ تَمسّكه...
# 8842    بنفسي أنت وروحي يا رسول، والله ما ضرك ما قال...
# 8843  #إلا_رسول_الله_يامودى " أنا كفيناك المستهزئين"...
# ...                                                 ...
# 9982    الديوث هو الذي لا يغار على عرضه، فكيف بمن لا...
# 9983    يا أتباع محمدﷺ اطمئنوا على مسرى نبيكم ، سيحر...
# 9988  يميناسنفدي المصطفى بجماجم  نفوسا واطفال وكل نس...
# 9991  #أوبس| د. عبدالحميد دشتي: حملة كبيرة لرجال الد...
# 9999  صلوات الله على رسول الله محمد وعلى آله وحفظ ال...
#
# [200 rows x 1 columns]

# %%
# selecting the first 200 tweets from both Arabic and English datasets
df_short_en_f = df_en.iloc[:200]
df_short_ar_f = df_ar.iloc[:200]
df_short_ar_f
# Out:
#                                                  tweet
# 0    إنَّ اللّٰه منتقمٌ لرسوله ـصلّى اللّٰه عليه وس...
# 1      #ارحل_يا_سيسي #إلا_رسول_الله_يامودى  #السيسي...
# 2      أبراج لوسيل في #قطر #إلا_رسول_الله #إلا_رسول...
# 3      " لاتدخروا وسعاً في نشر الخير " فمن استطاع أ...
# 4      عُمران خان: "الإساءة إلى النبي محمد ﷺ لا تُع...
# ..                                                 ...
# 427  يا مسلم، احتسب عند الله دفاعك عن جناب المصطفى ...
# 429    في كل مكان هناك مودي ، لكن مودي تويتر هو هذا...
# 430  أرح سمعك 🥀 القارئ: منصور السالمي 🍃 #إلا_رسول_ا...
# 433    لو كان الولاء للأرض ما ترك النبي مكة .. ولو ...
# 434    هل تعرف كيف تدافع عن النبي وأنت في بلدك؟ ألق...
#
# [200 rows x 1 columns]

# %%
# sending the request to the Perspective API
# importing time library
import time

# Define a dictionary to store the predicted toxicity probabilities scores
comment_scores = {}
i = 0
# the name of the dataset/ dataframe should be replaced with "df_short_ar_l" to analyze the last 200 Arabic tweets
for c in df_short_ar_f['tweet']: 
  i = i + 1
  data_dict = {
    'comment': {'text': c},
    'languages': ['ar'],
    'requestedAttributes': {'TOXICITY': {}}
  }
  response = requests.post(url=url, data=json.dumps(data_dict)) 
  response_dict = json.loads(response.content)
  print (response_dict) 
  comment_scores[c] = response_dict['attributeScores']['TOXICITY']['summaryScore']['value']
  if (i % 10) == 0:
    time.sleep(60)

# tweets textual content is saved in the keys
keys = comment_scores.keys()
# the predicted probabilities scores are saved in values
values = comment_scores.values()

print(comment_scores)
# Out:
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 269, 'score': {'value': 0.10699297, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.10699297, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 120, 'score': {'value': 0.09816993, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.09816993, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 101, 'score': {'value': 0.13835071, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.13835071, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 121, 'score': {'value': 0.026035614, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.026035614, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 123, 'score': {'value': 0.089041, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.089041, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 130, 'score': {'value': 0.043031808, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.043031808, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 262, 'score': {'value': 0.4292556, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.4292556, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 123, 'score': {'value': 0.087430015, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.087430015, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 125, 'score': {'value': 0.10892494, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.10892494, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 53, 'score': {'value': 0.025520578, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.025520578, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 121, 'score': {'value': 0.026722329, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.026722329, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 128, 'score': {'value': 0.015549194, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.015549194, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 125, 'score': {'value': 0.15246986, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.15246986, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 259, 'score': {'value': 0.37954164, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.37954164, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 120, 'score': {'value': 0.06971766, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.06971766, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 125, 'score': {'value': 0.09065199, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.09065199, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 282, 'score': {'value': 0.3897707, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.3897707, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 128, 'score': {'value': 0.0729142, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0729142, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 123, 'score': {'value': 0.024147147, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.024147147, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 127, 'score': {'value': 0.070516795, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.070516795, 'type': 'PROBABILITY'}}}, 'languages': ['ar'], 'detectedLanguages': ['ar']}

# %% [markdown]
# The same script above is used for both Arabic tweets dataframes by replacing the name of the dataframe. First applied to the "df_short_ar_f" and then applied to the "df_short_ar_l". The predictions scores are then saved into a dataframe and a CSV file to support further analysis and testing. We also save the file to Google drive as the folllowing:

# %%
# saving the predictions to a dataframe and then to a CSV file for further analysis
# replace the outputfile name with "Perspective_ar_last.csv" to save the predictions for the last 200 Arabic tweets
outputfile = "Perspective_ar_first.csv" 

df_Predictions_ar_f = pd.DataFrame({'tweet': keys, 'Predicted':values})

with open(outputfile, mode='w', newline='\n', encoding="utf-8-sig") as f:
            df_Predictions_ar_f.to_csv(f, sep=',', float_format='%.2f',
                              index=False, quoting=csv.QUOTE_MINIMAL)

# %%
# replace the file name with "Perspective_ar_last.csv" to save the predictions for the last 200 Arabic tweets to the drive
# you will need to grant permission to Colab to access your Google drive
file_name = "Perspective_ar_first.csv" 

from googleapiclient.http import MediaFileUpload
from googleapiclient.discovery import build
from google.colab import auth

auth.authenticate_user()
drive_service = build('drive', 'v3')

def save_file_to_drive(name, path):
  file_metadata = {'name': name, 'mimeType': 'application/octet-stream'}
  media = MediaFileUpload(path, mimetype='application/octet-stream', resumable=True)
  created = drive_service.files().create(body=file_metadata, media_body=media, fields='id').execute()
  
  return created

save_file_to_drive(file_name, file_name)
# Out:
# {'id': '1GU3OOPU5fSk1RCo2Vum3lqGUoO1JMg4f'}

# %%
# sending the request to the Perspective API
# importing time library
import time

# Define a dictionary to store the predicted toxicity probabilities scores
comment_scores = {}
i = 0
# the name of the dataset/ dataframe should be replaced with "df_short_en_l" to analyze the last 200 English tweets
for c in df_short_en_f['tweet']: #[:10]:
  i = i + 1
  data_dict = {
    'comment': {'text': c},
    'languages': ['en'],
    'requestedAttributes': {'TOXICITY': {}}
  }
  response = requests.post(url=url, data=json.dumps(data_dict)) 
  response_dict = json.loads(response.content)
  print (response_dict) 
  comment_scores[c] = response_dict['attributeScores']['TOXICITY']['summaryScore']['value']
  if (i % 10) == 0:
    time.sleep(60)

# tweets textual content is saved in the keys
keys = comment_scores.keys()
# the predicted probabilities scores are saved in values
values = comment_scores.values()

print(comment_scores)
# Out:
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 101, 'score': {'value': 0.002793996, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.002793996, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 121, 'score': {'value': 0.36667302, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.36667302, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 125, 'score': {'value': 0.089577995, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.089577995, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 126, 'score': {'value': 0.1024659, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.1024659, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 130, 'score': {'value': 0.00057702087, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.00057702087, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en', 'ga']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 123, 'score': {'value': 0.068918526, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.068918526, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 121, 'score': {'value': 0.14283726, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.14283726, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 278, 'score': {'value': 0.0051367874, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0051367874, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 301, 'score': {'value': 0.018742332, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.018742332, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 141, 'score': {'value': 0.3170379, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.3170379, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 246, 'score': {'value': 0.09816993, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.09816993, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 269, 'score': {'value': 0.04543531, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.04543531, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 156, 'score': {'value': 0.034962907, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.034962907, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 139, 'score': {'value': 0.00596978, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.00596978, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 152, 'score': {'value': 0.004425273, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.004425273, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en', 'gu-Latn']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 269, 'score': {'value': 0.045091953, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.045091953, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 209, 'score': {'value': 0.0060391957, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0060391957, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 79, 'score': {'value': 0.07091636, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.07091636, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 122, 'score': {'value': 0.0066639404, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0066639404, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 287, 'score': {'value': 0.046122026, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.046122026, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 265, 'score': {'value': 0.008260509, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.008260509, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 284, 'score': {'value': 0.00281135, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.00281135, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 123, 'score': {'value': 0.19535941, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.19535941, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 200, 'score': {'value': 0.2712817, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.2712817, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 310, 'score': {'value': 0.010898319, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.010898319, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 267, 'score': {'value': 0.015688026, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.015688026, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 212, 'score': {'value': 0.0044773347, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0044773347, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['mr-Latn', 'hi-Latn']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 202, 'score': {'value': 0.044748597, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.044748597, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en', 'om']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 253, 'score': {'value': 0.0017787862, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0017787862, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 295, 'score': {'value': 0.043375164, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.043375164, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 124, 'score': {'value': 0.013744377, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.013744377, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 123, 'score': {'value': 0.09387396, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.09387396, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 87, 'score': {'value': 0.0023254375, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0023254375, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 225, 'score': {'value': 0.012841969, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.012841969, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 251, 'score': {'value': 0.11794081, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.11794081, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 228, 'score': {'value': 0.050585672, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.050585672, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 74, 'score': {'value': 0.0027245798, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0027245798, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en', 'lb']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 113, 'score': {'value': 0.023460433, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.023460433, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 116, 'score': {'value': 0.12116077, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.12116077, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 195, 'score': {'value': 0.1464265, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.1464265, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 138, 'score': {'value': 0.0021866055, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0021866055, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 78, 'score': {'value': 0.015410362, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.015410362, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 125, 'score': {'value': 0.0034881562, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0034881562, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 174, 'score': {'value': 0.001405675, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.001405675, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 267, 'score': {'value': 0.06771983, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.06771983, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 233, 'score': {'value': 0.21539254, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.21539254, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 245, 'score': {'value': 0.02517722, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.02517722, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 252, 'score': {'value': 0.12180476, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.12180476, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 169, 'score': {'value': 0.0022560214, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0022560214, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 234, 'score': {'value': 0.03856816, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.03856816, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 270, 'score': {'value': 0.022945397, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.022945397, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 121, 'score': {'value': 0.08581903, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.08581903, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 125, 'score': {'value': 0.038224805, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.038224805, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 97, 'score': {'value': 0.0012755198, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0012755198, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 286, 'score': {'value': 0.011870144, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.011870144, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 275, 'score': {'value': 0.11600884, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.11600884, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 276, 'score': {'value': 0.017631676, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.017631676, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 259, 'score': {'value': 0.29021257, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.29021257, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 267, 'score': {'value': 0.0022733754, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0022733754, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 106, 'score': {'value': 0.001561861, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.001561861, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 102, 'score': {'value': 0.00013612052, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.00013612052, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en', 'mr-Latn', 'te-Latn']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 103, 'score': {'value': 0.0018568792, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0018568792, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 125, 'score': {'value': 0.11085691, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.11085691, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 239, 'score': {'value': 0.01228664, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.01228664, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 297, 'score': {'value': 0.0069416044, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0069416044, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 130, 'score': {'value': 0.14956708, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.14956708, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 154, 'score': {'value': 0.010967735, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.010967735, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 232, 'score': {'value': 0.0041996706, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0041996706, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 278, 'score': {'value': 0.18154536, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.18154536, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 157, 'score': {'value': 0.00021909439, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.00021909439, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['rw', 'om', 'ilo']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 97, 'score': {'value': 0.00094579364, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.00094579364, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 302, 'score': {'value': 0.0038699445, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0038699445, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 122, 'score': {'value': 0.002932828, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.002932828, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 113, 'score': {'value': 0.019575324, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.019575324, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 201, 'score': {'value': 0.004546751, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.004546751, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 78, 'score': {'value': 0.0020477732, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0020477732, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 129, 'score': {'value': 0.008642297, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.008642297, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 264, 'score': {'value': 0.0036269883, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0036269883, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 122, 'score': {'value': 0.009857078, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.009857078, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 150, 'score': {'value': 0.031701013, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.031701013, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 125, 'score': {'value': 0.045091953, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.045091953, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 113, 'score': {'value': 0.006247444, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.006247444, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 66, 'score': {'value': 0.00090674707, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.00090674707, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 208, 'score': {'value': 0.16344422, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.16344422, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 110, 'score': {'value': 0.008364634, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.008364634, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 303, 'score': {'value': 0.001544507, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.001544507, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 165, 'score': {'value': 0.2286382, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.2286382, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en', 'id', 'te-Latn']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 236, 'score': {'value': 0.02397547, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.02397547, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 143, 'score': {'value': 0.006559816, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.006559816, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 304, 'score': {'value': 0.0018308482, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0018308482, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en', 'te-Latn']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 246, 'score': {'value': 0.00075923797, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.00075923797, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 218, 'score': {'value': 0.0039740684, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0039740684, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 233, 'score': {'value': 0.0019436493, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0019436493, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 180, 'score': {'value': 0.001613923, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.001613923, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 28, 'score': {'value': 0.008642297, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.008642297, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 220, 'score': {'value': 0.000741884, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.000741884, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 103, 'score': {'value': 0.0017093701, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0017093701, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 298, 'score': {'value': 0.020269485, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.020269485, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 111, 'score': {'value': 0.012841969, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.012841969, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 247, 'score': {'value': 0.21892473, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.21892473, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['ar', 'om']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 256, 'score': {'value': 0.0034708022, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0034708022, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 128, 'score': {'value': 0.119228795, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.119228795, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 284, 'score': {'value': 0.003054306, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.003054306, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 297, 'score': {'value': 0.030842619, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.030842619, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 197, 'score': {'value': 0.00094579364, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.00094579364, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en', 'ga']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 192, 'score': {'value': 0.22977416, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.22977416, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 210, 'score': {'value': 0.0017006932, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0017006932, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 272, 'score': {'value': 0.3905958, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.3905958, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 146, 'score': {'value': 0.02637897, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.02637897, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 169, 'score': {'value': 0.0168681, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0168681, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 143, 'score': {'value': 0.0041476088, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0041476088, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en', 'om']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 292, 'score': {'value': 0.0052409116, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0052409116, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 124, 'score': {'value': 0.08050597, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.08050597, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 167, 'score': {'value': 0.009232334, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.009232334, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 144, 'score': {'value': 0.024662184, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.024662184, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 93, 'score': {'value': 0.57027644, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.57027644, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 121, 'score': {'value': 0.004928539, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.004928539, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 122, 'score': {'value': 0.040284947, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.040284947, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['om', 'ar', 'ur']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 126, 'score': {'value': 0.035649624, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.035649624, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 128, 'score': {'value': 0.036851373, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.036851373, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 253, 'score': {'value': 0.15001574, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.15001574, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 122, 'score': {'value': 0.0035922804, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0035922804, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 300, 'score': {'value': 0.2590451, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.2590451, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 307, 'score': {'value': 0.15276173, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.15276173, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 196, 'score': {'value': 0.00084166956, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.00084166956, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 258, 'score': {'value': 0.006108612, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.006108612, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 113, 'score': {'value': 0.013397297, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.013397297, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 176, 'score': {'value': 0.0028460578, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0028460578, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 97, 'score': {'value': 0.01263372, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.01263372, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 122, 'score': {'value': 0.019714156, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.019714156, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 219, 'score': {'value': 0.00068114494, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.00068114494, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 251, 'score': {'value': 0.1423886, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.1423886, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 213, 'score': {'value': 0.011106567, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.011106567, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 192, 'score': {'value': 0.0012147808, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0012147808, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 122, 'score': {'value': 0.009371166, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.009371166, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 141, 'score': {'value': 0.006212736, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.006212736, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 128, 'score': {'value': 0.09709594, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.09709594, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 270, 'score': {'value': 0.056931525, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.056931525, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 302, 'score': {'value': 0.0020911584, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0020911584, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 271, 'score': {'value': 0.0070457286, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0070457286, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 198, 'score': {'value': 0.0070110206, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0070110206, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 124, 'score': {'value': 0.1668969, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.1668969, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['ar']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 156, 'score': {'value': 0.008711713, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.008711713, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 123, 'score': {'value': 0.16275369, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.16275369, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['mr-Latn', 'te-Latn']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 301, 'score': {'value': 0.004581459, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.004581459, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 95, 'score': {'value': 0.0018915873, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0018915873, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 88, 'score': {'value': 0.008156385, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.008156385, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 111, 'score': {'value': 0.31661135, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.31661135, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en', 'sl']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 192, 'score': {'value': 0.006559816, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.006559816, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 122, 'score': {'value': 0.15001574, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.15001574, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 127, 'score': {'value': 0.19716066, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.19716066, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 91, 'score': {'value': 0.014646785, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.014646785, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 89, 'score': {'value': 0.012217224, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.012217224, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 221, 'score': {'value': 0.0051714955, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0051714955, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 128, 'score': {'value': 0.013952625, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.013952625, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 212, 'score': {'value': 0.02193547, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.02193547, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 123, 'score': {'value': 0.0043905647, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0043905647, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 111, 'score': {'value': 0.035649624, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.035649624, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 238, 'score': {'value': 0.19862764, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.19862764, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 121, 'score': {'value': 0.10031791, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.10031791, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 311, 'score': {'value': 0.03736641, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.03736641, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 101, 'score': {'value': 0.0014317059, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0014317059, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 271, 'score': {'value': 0.11021292, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.11021292, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['hi']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 53, 'score': {'value': 0.0023254375, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0023254375, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 129, 'score': {'value': 0.014438537, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.014438537, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 126, 'score': {'value': 0.105704986, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.105704986, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 306, 'score': {'value': 0.0011280107, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0011280107, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 239, 'score': {'value': 0.00596978, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.00596978, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 122, 'score': {'value': 0.16151784, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.16151784, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 146, 'score': {'value': 0.0050326632, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0050326632, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 121, 'score': {'value': 0.052935857, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.052935857, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 138, 'score': {'value': 0.11343288, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.11343288, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 111, 'score': {'value': 0.0055532837, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0055532837, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 241, 'score': {'value': 0.0069763125, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0069763125, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 259, 'score': {'value': 0.00087203906, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.00087203906, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 265, 'score': {'value': 0.004251733, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.004251733, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 249, 'score': {'value': 0.3437808, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.3437808, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 118, 'score': {'value': 0.0018221712, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0018221712, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 127, 'score': {'value': 0.05773066, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.05773066, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 95, 'score': {'value': 0.006455692, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.006455692, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 163, 'score': {'value': 0.0016920161, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0016920161, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 129, 'score': {'value': 0.00087203906, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.00087203906, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['hi-Latn']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 128, 'score': {'value': 0.22510603, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.22510603, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 207, 'score': {'value': 0.1894391, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.1894391, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 171, 'score': {'value': 0.0012494888, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0012494888, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 145, 'score': {'value': 0.017701091, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.017701091, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 263, 'score': {'value': 0.03444787, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.03444787, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 131, 'score': {'value': 0.055732824, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.055732824, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 265, 'score': {'value': 0.14552918, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.14552918, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 298, 'score': {'value': 0.029469188, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.029469188, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 269, 'score': {'value': 0.0005943749, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0005943749, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en', 'om', 'ilo']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 115, 'score': {'value': 0.00069416047, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.00069416047, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 275, 'score': {'value': 0.0025336856, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0025336856, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 124, 'score': {'value': 0.14911842, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.14911842, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 268, 'score': {'value': 0.09548495, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.09548495, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 125, 'score': {'value': 0.3411882, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.3411882, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 121, 'score': {'value': 0.016104523, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.016104523, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 127, 'score': {'value': 0.058929358, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.058929358, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 69, 'score': {'value': 0.0007722535, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.0007722535, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'attributeScores': {'TOXICITY': {'spanScores': [{'begin': 0, 'end': 149, 'score': {'value': 0.024147147, 'type': 'PROBABILITY'}}], 'summaryScore': {'value': 0.024147147, 'type': 'PROBABILITY'}}}, 'languages': ['en'], 'detectedLanguages': ['en']}
# {'  How President of India is elected?  #India #president #presidentialelection https://t.co/UwNzM6jOOi': 0.002793996, '  The accused were first brutally beaten up by the villagers, after which they sprinkled kerosene to burn them alive alo…': 0.36667302, '  Protests by #BUET students in #India against the insult to the Holy #ProphetMuhammad (PBUH) by the Hindutva #BJP.  #NupurS…': 0.089577995, '  Prophet Muhammad PBUH came as a MERCY for the Whole Mankind and Eradicated Discrimination from the Whole World. #Stopinsult…': 0.1024659, '  #Accessible #India Campaign  #accessibleindiacampaign #accessibleindia #indiacampaign #upsc #cse #whyinnews #sugamyabharatabhiy…': 0.00057702087, '  Which country was ranked second? Ukraine? There is a strong reason as to why these "indexes" must not be taken seriously…': 0.068918526, '  The Rupee has never been valued as less as it has consistently been doing under this BJP govt. PM Modi used to be worr…': 0.14283726, '✅#Russia will be able to sell some of that product, at a discount, to other buyers, such as #China and #India. https://t.co/Two6RlYt9l https://t.co/nwUMoeErGl https://t.co/FklGpCSxyX https://t.co/Udl30DSCLC https://t.co/NJaWd6g7ja https://t.co/sDrSDEMiCO https://t.co/tKTzwyEIfd': 0.0051367874, 'Make your customize bags for your events...!!!  #cottonbag #canvasbag #jutebag #totebag #blivus #Manufacutring #exporter #manufacturer #cottonbags #canvasbags #jutebags #printedbag #cotton #canvas #jute #bag #nature #ahmedabad #india #hotel #resort #beatplasticpollution #event https://t.co/DiY75P5hgn': 0.018742332, 'Children of #MLA in #Bangluru &amp; #Hyderabad carrying the important task of unearned privelege forward. Shameless. #VVIP #CULTURE of #India': 0.3170379, " One question dear  , If you really possess the powers that you claim to possess, why don't you use your powers to cause a global contact event with the extraterrestrials? #ufotwitter #India #Brazil #China #Ukraine #Russia #aliens #JoeRogan #NASA": 0.09816993, "One question dear  , If you really possess the powers that you claim to possess, why don't you use your powers to cause a global contact event with the extraterrestrials? #ufotwitter #India #Brazil #China #Ukraine #Russia #aliens #JoeRogan #NASA https://t.co/0m8D6hOtRE": 0.04543531, 'Lesson(🧵) : The results of #PRC aggression against #India will be very different from the results of PRC aggression against #Taiwan https://t.co/07kurAU3XV': 0.034962907, '#amirliaquat rest in peace memer😭🕊️❤️. Love from India. your meme will always be in our heart❤️. #india #Pakistan https://t.co/ZI69v7KNrT': 0.00596978, 'Ruturaj Gaikwad caught out!!   #India #SouthAfrica #IndvsSA #Sportsmarketing #sportsarena  #T20 #T20Series #Cricket #Cricket2022 https://t.co/TYfcay0WBZ': 0.004425273, "One question dear  , If you really possess the powers that you claim to possess, why don't you use your powers to cause a global contact event with the extraterrestrials? #ufotwitter #India #Brazil #China #Ukraine #Russia #aliens #JoeRogan #NASA https://t.co/kJXDFCwapr": 0.045091953, 'During his visit to #India, Iranian Foreign Minister  arrived in Mumbai on Thursday evening to attend a meeting with trade and economic agents from both the private and public sectors.  https://t.co/pYohnJVumI': 0.0060391957, 'NEI Herald Australia:  #India #Wheat #EU #Gulf #BanList https://t.co/k1ESJg8Agh': 0.07091636, '#India unlikely to witness #fourthwave unless new #COVID19 variant reported, says health expert    https://t.co/bi5X7gLZZK': 0.0066639404, "One question dear  , If you really possess the powers that you claim to possess, why don't you use your powers to cause a global contact event with the extraterrestrials? #ufotwitter #Japan #Indonesia #India #Brazil #China #Ukraine #Russia #aliens #JoeRogan #NASA https://t.co/NJFzxCgi6T": 0.046122026, 'Welcome to https://t.co/E1CeColoSl online casino India.  Toss updates!! South Africa has won the toss and decided to bowl Visit https://t.co/hMswljKDga for more informatio ...

# %%
# saving the predictions to a dataframe and then to a CSV file for further analysis
# replace the outputfile name with "Perspective_en_last.csv" to save the predictions for the last 200 English tweets

outputfile = "Perspective_en_first.csv" 
df_Predictions_en_f = pd.DataFrame({'tweet': keys, 'Predicted':values})

with open(outputfile, mode='w', newline='\n', encoding="utf-8-sig") as f:
            df_Predictions_en_f.to_csv(f, sep=',', float_format='%.2f',
                              index=False, quoting=csv.QUOTE_MINIMAL)
                              

# saving the file to your Google drive
# replace the file name with "Perspective_ar_last.csv" to save the predictions for the last 200 Arabic tweets to the drive
# you will need to grant permission to Colab to access your Google drive
file_name = "Perspective_en_first.csv" 

from googleapiclient.http import MediaFileUpload
from googleapiclient.discovery import build
from google.colab import auth

auth.authenticate_user()
drive_service = build('drive', 'v3')

def save_file_to_drive(name, path):
  file_metadata = {'name': name, 'mimeType': 'application/octet-stream'}
  media = MediaFileUpload(path, mimetype='application/octet-stream', resumable=True)
  created = drive_service.files().create(body=file_metadata, media_body=media, fields='id').execute()
  
  return created

save_file_to_drive(file_name, file_name)

# %% [markdown]
# # Evaluating Samples from the Results:

# %% [markdown]
# The datasets used in this exercise are not labelled. We do not have gold labels to check and evaluate the predictions toxicity scores and use the standard performance measures, such as recall, F-1, precision, or accuracy. Thus, we will be very limited in our evaluation and apply only two methods: manual inspection and general descriptive statistics. We encourage the readers to try other methods to better understand the issue and evaluate the accuracy of the outputs.

# %%
# printing samples from the predictions from each datasets
# Sample from the first 200 Arabic tweets results
df_ar_f = pd.read_csv('/content/Perspective_ar (1).csv', header = 0)
df_ar_f
# Out:
#                                                  tweet  Predicted
# 0    إنَّ اللّٰه منتقمٌ لرسوله ـصلّى اللّٰه عليه وس...       0.10
# 1      #ارحل_يا_سيسي #إلا_رسول_الله_يامودى  #السيسي...       0.10
# 2      أبراج لوسيل في #قطر #إلا_رسول_الله #إلا_رسول...       0.14
# 3      " لاتدخروا وسعاً في نشر الخير " فمن استطاع أ...       0.03
# 4      عُمران خان: "الإساءة إلى النبي محمد ﷺ لا تُع...       0.09
# ..                                                 ...        ...
# 195  يا مسلم، احتسب عند الله دفاعك عن جناب المصطفى ...       0.11
# 196    في كل مكان هناك مودي ، لكن مودي تويتر هو هذا...       0.23
# 197  أرح سمعك 🥀 القارئ: منصور السالمي 🍃 #إلا_رسول_ا...       0.02
# 198    لو كان الولاء للأرض ما ترك النبي مكة .. ولو ...       0.18
# 199    هل تعرف كيف تدافع عن النبي وأنت في بلدك؟ ألق...       0.10
#
# [200 rows x 2 columns]

# %%
# Sample from the last 200 Arabic tweets results
df_ar_l = pd.read_csv('/content/Perspective_ar_last.csv', header = 0)
df_ar_l
# Out:
#                                                  tweet  Predicted
# 0    اللهم صلي وسلم وزد وبارك علي اشرف خلق الله سيد...       0.04
# 1    #إلا_رسول_الله_يامودى #مقاطعة_المنتجات_الهندية...       0.09
# 2      ..  إنما يَرفعُ الله الشّخصَ بِقَدرِ تَمسّكه...       0.04
# 3      بنفسي أنت وروحي يا رسول، والله ما ضرك ما قال...       0.07
# 4    #إلا_رسول_الله_يامودى " أنا كفيناك المستهزئين"...       0.05
# ..                                                 ...        ...
# 195    الديوث هو الذي لا يغار على عرضه، فكيف بمن لا...       0.13
# 196    يا أتباع محمدﷺ اطمئنوا على مسرى نبيكم ، سيحر...       0.08
# 197  يميناسنفدي المصطفى بجماجم  نفوسا واطفال وكل نس...       0.17
# 198  #أوبس| د. عبدالحميد دشتي: حملة كبيرة لرجال الد...       0.27
# 199  صلوات الله على رسول الله محمد وعلى آله وحفظ ال...       0.14
#
# [200 rows x 2 columns]

# %%
# Sample from the first 200 English tweets results
df_en_f = pd.read_csv('/content/Perspective_en (1).csv', header = 0)
df_en_f
# Out:
#                                                  tweet  Predicted
# 0      The idols of deities at a #Hindu temple have...       0.19
# 1      India: Kanpur:  Hundreds of Muslims Being Pi...       0.23
# 2      The Hindu police in Kanpur beat the Muslims ...       0.29
# 3      Where's the western feminist campaign to "sa...       0.29
# 4      Muslim woman’s husband was viciously beaten ...       0.35
# ..                                                 ...        ...
# 195    🧵Climate change exacerbated exceptional heat...       0.02
# 196  Nuhi in #India is still a few thousand dollars...       0.08
# 197  Top 5 Korean exchanges delist Litecoin, label ...       0.01
# 198  Go to https://t.co/GsWE44TGUW for more. #Stopi...       0.07
# 199   How couples go house by house asking for alms...       0.06
#
# [200 rows x 2 columns]

# %%
# Sample from the last 200 English tweets results
df_en_l = pd.read_csv('/content/Perspective_en_last.csv', header = 0)
df_en_l
# Out:
#                                                  tweet  Predicted
# 0      How President of India is elected?  #India #...       0.00
# 1      The accused were first brutally beaten up by...       0.37
# 2      Protests by #BUET students in #India against...       0.09
# 3      Prophet Muhammad PBUH came as a MERCY for th...       0.10
# 4      #Accessible #India Campaign  #accessibleindi...       0.00
# ..                                                 ...        ...
# 195    Police still not arrest nupur sharma.special...       0.34
# 196    NHAI sets new Guinness World Record, lays 75...       0.02
# 197    Little girl tied on rooftop in scorching hea...       0.06
# 198  Good Evening Friend's #India #TamilNadu #time ...       0.00
# 199  Afternoon all just a message to let you all kn...       0.02
#
# [200 rows x 2 columns]

# %% [markdown]
# Calculating general descriptive statistics for each part from the datasets using the .describe() method.

# %%
# The first 200 Arabic tweets
df_ar_f_stat = df_ar_f.describe()
df_ar_f_stat
# Out:
#         Predicted
# count  200.000000
# mean     0.110950
# std      0.088315
# min      0.000000
# 25%      0.047500
# 50%      0.085000
# 75%      0.160000
# max      0.430000

# %%
# The last 200 Arabic tweets
df_ar_l_stat = df_ar_l.describe()
df_ar_l_stat
# Out:
#        Predicted
# count  200.00000
# mean     0.11800
# std      0.09762
# min      0.01000
# 25%      0.04000
# 50%      0.08000
# 75%      0.18250
# max      0.46000

# %%
# The first 200 English tweets
df_en_f_stat = df_en_f.describe()
df_en_f_stat
# Out:
#         Predicted
# count  200.000000
# mean     0.119100
# std      0.139306
# min      0.000000
# 25%      0.010000
# 50%      0.045000
# 75%      0.202500
# max      0.730000

# %%
# The last 200 English tweets
df_en_l_stat = df_en_l.describe()
df_en_l_stat
# Out:
#         Predicted
# count  200.000000
# mean     0.057500
# std      0.090674
# min      0.000000
# 25%      0.000000
# 50%      0.010000
# 75%      0.082500
# max      0.570000

# %% [markdown]
# The results report very similar results among the partitions of each language. On general, the conversation is not toxic and users are using clean language in their tweets. We merge the partitions of each language and analyze the results further based on the predicted score for each language seperatly.

# %%
# Merging the Arabic datasets
ar_data = [df_ar_f, df_ar_l]
dataset_ar = pd.concat(ar_data)
dataset_ar
# Out:
#                                                  tweet  Predicted
# 0    إنَّ اللّٰه منتقمٌ لرسوله ـصلّى اللّٰه عليه وس...       0.10
# 1      #ارحل_يا_سيسي #إلا_رسول_الله_يامودى  #السيسي...       0.10
# 2      أبراج لوسيل في #قطر #إلا_رسول_الله #إلا_رسول...       0.14
# 3      " لاتدخروا وسعاً في نشر الخير " فمن استطاع أ...       0.03
# 4      عُمران خان: "الإساءة إلى النبي محمد ﷺ لا تُع...       0.09
# ..                                                 ...        ...
# 195    الديوث هو الذي لا يغار على عرضه، فكيف بمن لا...       0.13
# 196    يا أتباع محمدﷺ اطمئنوا على مسرى نبيكم ، سيحر...       0.08
# 197  يميناسنفدي المصطفى بجماجم  نفوسا واطفال وكل نس...       0.17
# 198  #أوبس| د. عبدالحميد دشتي: حملة كبيرة لرجال الد...       0.27
# 199  صلوات الله على رسول الله محمد وعلى آله وحفظ ال...       0.14
#
# [400 rows x 2 columns]

# %%
# Merging the English datasets
en_data = [df_en_f, df_en_l]
dataset_en = pd.concat(en_data)
dataset_en
# Out:
#                                                  tweet  Predicted
# 0      The idols of deities at a #Hindu temple have...       0.19
# 1      India: Kanpur:  Hundreds of Muslims Being Pi...       0.23
# 2      The Hindu police in Kanpur beat the Muslims ...       0.29
# 3      Where's the western feminist campaign to "sa...       0.29
# 4      Muslim woman’s husband was viciously beaten ...       0.35
# ..                                                 ...        ...
# 195    Police still not arrest nupur sharma.special...       0.34
# 196    NHAI sets new Guinness World Record, lays 75...       0.02
# 197    Little girl tied on rooftop in scorching hea...       0.06
# 198  Good Evening Friend's #India #TamilNadu #time ...       0.00
# 199  Afternoon all just a message to let you all kn...       0.02
#
# [400 rows x 2 columns]

# %%
# the mean of the overall Arabic dataset
mean_avg = dataset_ar.mean()
float(mean_avg)
# Out:
# 0.11447500000000002

# %%
# printing an ordered datasets
dataset_ar = dataset_ar.sort_values("Predicted")
dataset_ar
# Out:
#                                                  tweet  Predicted
# 55     ذكر الذهبي في سير أعلام النبلاء عن الإمام ما...       0.00
# 184    قال النبي محمد ﷺ: "ما من امرئٍ يخذل امرءًا م...       0.01
# 25     قال النبي محمد ﷺ: "ما من امرئٍ يخذل امرءًا م...       0.01
# 191  #إلا_رسول_الله_يامودى  اللهم صل علي سيدنا ونبي...       0.02
# 161    حى على المقاطعه يوم جديد على عملك شهيد مستمر...       0.02
# ..                                                 ...        ...
# 181    ذاك السياسي الهندي القذر الذي اذى بلسانه عرض...       0.41
# 131  يعبد البقر و يأكل روث البقر أكيد ما فيه أنجس م...       0.43
# 6    #الوراق_عشوه_الكلاب#مصر_بتنجح_الخونه_تنبح لعنه...       0.43
# 139  بتوجيه من حفدة القردة والخنازير صحيفة العرب ال...       0.44
# 122  شوف عمرك كبير بس عقلك عقل مدري ايش حتى حيوان ي...       0.46
#
# [400 rows x 2 columns]

# %%
# printing an ordered datasets
dataset_en = dataset_en.sort_values("Predicted")
dataset_en
# Out:
#                                                  tweet  Predicted
# 67   Investments in #India’s #renewableenergy secto...       0.00
# 118    Lead Groom Artist required at Technicolor St...       0.00
# 110  🇮🇳 🇿🇦  Who will win this shiny trophy? 🏆  #IND...       0.00
# 114  weather in banur #India 15 #Days #Weather #for...       0.00
# 111  India First Startup Meet; Kerala on the brink ...       0.00
# ..                                                 ...        ...
# 45     "#Modi govt has provided political+legal cov...       0.45
# 168    Indian Muslims ‘need to give up 3 concepts’-...       0.54
# 159    #Stopinsulting_ProphetMuhammad this is the p...       0.54
# 115      What a silly post questioning your basic u...       0.57
# 181    well, Is sudeep bad? tell him that is wife i...       0.73
#
# [400 rows x 2 columns]

# %%
# counting frequencies of toxicity scores
dataset_en.Predicted.value_counts()
# Out:
# 0.00    88
# 0.01    79
# 0.02    33
# 0.03    19
# 0.04    17
# 0.23    13
# 0.05    11
# 0.15     9
# 0.10     9
# 0.16     9
# 0.06     8
# 0.29     8
# 0.12     8
# 0.27     7
# 0.11     7
# 0.07     6
# 0.14     5
# 0.17     5
# 0.20     5
# 0.34     5
# 0.09     5
# 0.18     4
# 0.32     4
# 0.19     3
# 0.13     3
# 0.08     2
# 0.39     2
# 0.41     2
# 0.45     2
# 0.43     2
# 0.38     2
# 0.54     2
# 0.22     2
# 0.36     2
# 0.42     1
# 0.57     1
# 0.31     1
# 0.37     1
# 0.35     1
# 0.33     1
# 0.30     1
# 0.28     1
# 0.26     1
# 0.24     1
# 0.21     1
# 0.73     1
# Name: Predicted, dtype: int64

# %%
# print the tweet with the highest toxicity score
last = dataset_en.iloc[-1:]
last.tweet
# Out:
# 181      well, Is sudeep bad? tell him that is wife i...
# Name: tweet, dtype: object

# %%
# printing a histogram for the results based on the frequencies
dataset_en['Predicted'].value_counts().plot(kind='hist')

# %%
# counting frequencies of toxicity scores
dataset_ar.Predicted.value_counts()
# Out:
# 0.03    41
# 0.04    36
# 0.05    29
# 0.02    28
# 0.07    26
# 0.06    22
# 0.08    20
# 0.09    19
# 0.13    16
# 0.10    16
# 0.23    16
# 0.16    13
# 0.14    11
# 0.27    11
# 0.17    10
# 0.11     9
# 0.15     8
# 0.12     8
# 0.20     8
# 0.19     7
# 0.18     5
# 0.28     4
# 0.39     4
# 0.24     4
# 0.32     3
# 0.30     3
# 0.26     3
# 0.29     2
# 0.21     2
# 0.43     2
# 0.01     2
# 0.35     2
# 0.44     1
# 0.41     1
# 0.38     1
# 0.00     1
# 0.36     1
# 0.34     1
# 0.31     1
# 0.25     1
# 0.22     1
# 0.46     1
# Name: Predicted, dtype: int64

# %%
# printing a histogram for the results based on the frequencies
dataset_ar['Predicted'].value_counts().plot(kind='hist')

# %%
# print the tweet with the highest toxicity score
last = dataset_ar.iloc[-1:]
last.tweet
# Out:
# 122    شوف عمرك كبير بس عقلك عقل مدري ايش حتى حيوان ي...
# Name: tweet, dtype: object
